# %%
print('Hello from main!')
# Out:
# Hello from main!

# %%
print('Hello from repository!')
# Out:
# Hello from repository!

# %%
1+2
# Out:
# 3

# %%
3+4
# Out:
# 7

# %%
print ('you are marvelous, just know it')
# Out:
# you are marvelous, just know it

# %%
4+5
# Out:
# 9
